# %%
#!/usr/bin/env python3

import numpy as np
#import tensorflow.keras as keras
import pandas as pd
import sys
import tensorflow.compat.v1 as tf
import timeit
import time
import csv
import datetime
import scipy.io
import scipy.optimize
from scipy import optimize
from scipy.interpolate import CubicSpline
from matplotlib.pylab import rcParams
#from statsmodels.tsa.holtwinters import SimpleExpSmothing, Holt
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import explained_variance_score
from matplotlib import pyplot as plt

tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
today = '2022-05-7' # Update this to include more data 
days = pd.date_range(start='2021-11-29',end=today)
dd = np.arange(len(days))
dd.shape
# Out:
# (160,)

# %% [markdown]
# ### Constant Model

# %%
##########################################################################################################
# load data

df1 = pd.read_csv('Omicron_Italy.csv')


##########################################################################################################
# process data
today = '2022-05-08' # Update this to include more data 
days = pd.date_range(start='2021-11-30',end=today)
dd = np.arange(len(days))

# total_cases = [df1[day.strftime('%d/%m/%Y')][0] for day in days]
# total_cases = [df1[day.strftime('%-m/%-d/%Y')].sum() for day in days] 

#total_cases = [df1[day.strftime('%-m/%-d/%Y')][0] for day in days]
total_cases = [df1[day.strftime('%Y-%m-%d')][0] for day in days]

# import statistics

# def detect_outlier(data_1):
#     threshold = 1
#     mean_1 = statistics.mean(data_1)
#     std_1 = statistics.stdev(data_1)
#     result_dataset = [y  for y in data_1 if abs((y - mean_1)/std_1)<=threshold ]
#     return result_dataset

# if __name__=="__main__":
#     dataset = total_cases
#     result_dataset = detect_outlier(dataset)
#     print(result_dataset)
    
    
    
dff =pd.DataFrame(np.array(total_cases))


new_total =dff.rolling(7).mean()
new_total =np.array(new_total[6:]).reshape((-1,1))
firstSix =np.array(total_cases[:6]).reshape((-1,1))
modified_data = np.vstack((firstSix, new_total))    


t = np.reshape(dd, [-1])
I = np.reshape(modified_data, [-1])

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

new_I = NormalizeData(I) # scaled btw 0 and 1

# generating more data points for training
nd = 160
cs1 = CubicSpline(t,new_I)

Td = np.linspace(0,160,nd)

cs_I = cs1(Td)

# %%
plt.plot(cs_I)

# %% [markdown]
# ### Boxplot

# %%
# import seaborn as sns
# sns.boxplot(total_cases)

# %%
#I

# %%
class PINN_constantParam:
    # Initialize the class
    def __init__(self, t, I, layers, lb, ub):
        
        self.lb = lb
        self.ub = ub
        
        self.t = t
        
        self.I = I
        
        self.layers = layers
        
        self.weights, self.biases = self.initialize_NN(layers)
        
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # initialize params
        self.beta = tf.Variable([1000.0], dtype=tf.float32)
        self.Nf = tf.Variable([1.0], dtype=tf.float32)
        self.kappa = tf.Variable([1.0], dtype=tf.float32)
        
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.I_tf = tf.placeholder(tf.float32, shape=[None, self.I.shape[1]])
                
        
        self.I_predL = self.net_Logistic(self.t_tf)
        
        self.l1, self.l2 = self.net_l(self.t_tf)
        
        self.loss = tf.reduce_mean(tf.square(self.I_tf - self.I_predL)) + \
            tf.reduce_mean(tf.square(self.l1)) + \
            tf.reduce_mean(tf.square(self.l2))
        
        self.optimizer = tf.train.AdamOptimizer(1e-2)
        self.train_op = self.optimizer.minimize(self.loss)
        self.loss_log = []
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, t, weights, biases):
        num_layers = len(weights) + 1
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        #Y = tf.nn.softplus(tf.add(tf.matmul(H, W), b))
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    
    def net_Logistic(self, t):
        Logistic = self.neural_net(t, self.weights, self.biases)
        I = Logistic
        return I
    
    
   
    
    def net_l(self, t):
        Nf = self.Nf
        beta = self.beta
        kappa = self.kappa
        
        I = self.net_Logistic(t)
        I_t = tf.gradients(I, t)[0]
        
        l1 = I - (Nf/(1+beta*tf.math.exp(-kappa*t))) 
        l2 = I_t - (kappa*(I-(1/Nf)*I**2))
        
        return l1, l2
    
    
    def train(self, nIter):
        tf_dict = {self.t_tf: self.t, self.I_tf: self.I}
        start_time = timeit.default_timer()
        tf_dict = {self.t_tf: self.t, self.I_tf: self.I}
        

        for it in tqdm(range(nIter)):
            self.sess.run(self.train_op, tf_dict)
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                self.loss_log.append(loss_value)
                beta_value = self.sess.run(self.beta)
                kappa_value = self.sess.run(self.kappa)
                Nf_value = self.sess.run(self.Nf)
                start_time = timeit.default_timer()
            
            
            # calculate loss with test data
        
        
    def predict(self, t_star):
        tf_dict = {self.t_tf: t_star}
        
        I_star = self.sess.run(self.I_predL, tf_dict)
        
        return I_star

# %%
# #########################################################################################################
# # training and testing the network

# niter = 50000  # number of Epochs
# layers = [1, 64, 64, 64, 1]
# t_data = Td.flatten()[:,None]
# I_data = cs_I.flatten()[:,None]    

# from sklearn.model_selection import train_test_split

# # random splits

# T_train, T_test, I_train, I_test = train_test_split(t_data, I_data, test_size = 0.2, random_state = 23)
# T_train = np.sort(T_train, axis = 0)
# T_test = np.sort(T_test, axis = 0)
# I_train = np.sort(I_train, axis = 0)
# I_test = np.sort(I_test, axis = 0)

# # Doman bounds
# lb = t_data.min(0)
# ub = t_data.max(0)

# model = PINN_constantParam(T_test, I_test, layers, lb, ub)
# model.train(niter)

# %%
##########################################################################################################
# training the network

niter = 25000  # number of Epochs
layers = [1, 20, 20, 20, 20, 1]
t_train = Td.flatten()[:,None]
I_train = cs_I.flatten()[:,None] 
#I_train = cs_I.flatten()[:,None]    

# Doman bounds
lb = t_train.min(0)
ub = t_train.max(0)

model = PINN_constantParam(t_train, I_train, layers, lb, ub)
model.train(niter)

# %%
# prediction
I_predL = model.predict(t_train)

# %%
mse_train_loss = model.loss_log
rmse_train_loss = np.sqrt(mse_train_loss)
#print("rmse_train_loss:",*["%.8f"%(x) for x in rmse_train_loss[0:400]])

# flatten array
T0L = Td.flatten()
T1L = t_train.flatten()

# re-scale data
I0L = np.min(I) + (np.max(I) - np.min(I))*cs_I.flatten()
I1L = np.min(I) + (np.max(I) - np.min(I))*I_predL.flatten()

# convert float to list
T0L = T0L[0:nd].tolist()
T1L = T1L[0:nd].tolist()
I0L = I0L[0:nd].tolist()
I1L = I1L[0:nd].tolist()

# print("days:",*["%.8f"%(x) for x in T0[0:nd]])
# print("time:",*["%.8f"%(x) for x in T1[0:nd]])
# print("cases:",*["%.8f"%(x) for x in I0[0:nd]])
# print("infectd:",*["%.8f"%(x) for x in I1[0:nd]])

beta_valueL = model.sess.run(model.beta)
kappa_valueL = model.sess.run(model.kappa)
Nf_valueL = model.sess.run(model.Nf)

# learned parameters
print("beta:",*["%.8f"%(x) for x in beta_valueL])
print("kappa:",*["%.8f"%(x) for x in kappa_valueL])
print("Nf:",*["%.8f"%(x) for x in (np.min(I0L) + (np.max(I0L) - np.min(I0L)))*Nf_valueL])

##########################################################################################################

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter

fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title('Daily number of individual infectives in Italy ',fontsize = 20)
ax1.plot(T0L,I0L,'bo')
ax1.plot(T1L, I1L,'g')
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel('Daily Omicron Infection', fontsize = 20)
ax1.legend(('Omicron data','Constant Model'),loc='best',fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
rmse =np.sqrt(mean_squared_error(I0L, I1L))
rmse

# %%
corr_matrix = np.corrcoef(I0L, I1L)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))

# %%
mapep =  mean_absolute_percentage_error(I0L, I1L)
mapep

# %%
ev = explained_variance_score(I0L, I1L)
ev

# %% [markdown]
# ### Rational Model

# %%
class PINN_ExpAlpha:
    # Initialize the class
    def __init__(self, t, I,  layers1, lb, ub):
        
        self.lb = lb
        self.ub = ub
        
        self.t = t
        
        self.I = I
        
        self.layers1 = layers1
        
        
        self.weights1, self.biases1 = self.initialize_NN(layers1)
        
        
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.beta = tf.Variable([7500.0], dtype=tf.float32)
        self.kappa = tf.Variable([1.0], dtype=tf.float32)
        self.d = tf.Variable([1.0], dtype=tf.float32)
        self.Nf = tf.Variable([1.0], dtype=tf.float32)
        
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.I_tf = tf.placeholder(tf.float32, shape=[None, self.I.shape[1]])
        
        
        self.I_predR = self.net_Logistic(self.t_tf)
        self.alpha_predR = self.alphaFunc(self.t_tf)
        
        self.l1 = self.net_l(self.t_tf)
        
        self.loss = tf.reduce_mean(tf.square(self.I_tf - self.I_predR)) + \
                    tf.reduce_mean(tf.square(self.l1)) 
            
            
             
            
        
        self.optimizer = tf.train.AdamOptimizer(1e-2)
        self.train_op = self.optimizer.minimize(self.loss)
        self.loss_log = []
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, t, layers1, weights1, biases1):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights1[l]
            b = biases1[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights1[-1]
        b = biases1[-1]
        #Y = tf.nn.softplus(tf.add(tf.matmul(H, W), b))
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    def net_Logistic(self, t):
        Logistic = self.neural_net(t, self.layers1, self.weights1, self.biases1)
        I = Logistic
        return I
    
   
    def alphaFunc(self,t):
        d = self.d
        kappa = self.kappa
        b = kappa*d / (1 + d*t)
        return b
    
    
    def net_l(self, t):
        Nf = self.Nf
        beta = self.beta
        kappa = self.kappa
        d = self.d
        alpha = self.alphaFunc(t)
        
        I = self.net_Logistic(t)
        l1 = I - (Nf/(1+beta*(1 + d*t)**-kappa))
        return l1
        
    def train(self, nIter):
        tf_dict = {self.t_tf: self.t, self.I_tf: self.I}
        start_time = timeit.default_timer()

        for it in tqdm(range(nIter)):
            self.sess.run(self.train_op, tf_dict)
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                self.loss_log.append(loss_value)
                beta_value = self.sess.run(self.beta)
                d_value = self.sess.run(self.d)
                kappa_value = self.sess.run(self.kappa)
                Nf_value = self.sess.run(self.Nf)
                start_time = timeit.default_timer()
        
        
        
    def predict(self, t_star):
        tf_dict = {self.t_tf: t_star}
        
        
        I_star = self.sess.run(self.I_predR, tf_dict)
        
        alpha_star = self.sess.run(self.alpha_predR, tf_dict)
        
        return I_star,  alpha_star

# %%
##########################################################################################################
# training the network

niter = 25000  # number of Epochs
layers1 = [1, 20, 20, 20, 20, 1]


t_train = Td.flatten()[:,None]
I_train = cs_I.flatten()[:,None]
    
#D_train = cs_D.flatten()[:,None]      

# Doman bounds
lb = t_train.min(0)
ub = t_train.max(0)

model = PINN_ExpAlpha(t_train, I_train, layers1, lb, ub)
model.train(niter)

# %%
# prediction
I_predR, alpha_predR = model.predict(t_train)

# %%
mse_train_loss = model.loss_log
rmse_train_loss = np.sqrt(mse_train_loss)
#print("rmse_train_loss:",*["%.8f"%(x) for x in rmse_train_loss[0:400]])

# flatten array
T0R = Td.flatten()
T1R = t_train.flatten()


# re-scale data
I0R = np.min(I) + (np.max(I) - np.min(I))*cs_I.flatten()
I1R = np.min(I) + (np.max(I) - np.min(I))*I_predR.flatten()
A1R = np.min(I) + (np.max(I) - np.min(I))*alpha_predR.flatten()
#TT1 = np.min(T0) + (np.max(T0) - np.min(T0))*tt

# convert float to list
T0R = T0R[0:nd].tolist()
T1R = T1R[0:nd].tolist()
I0R = I0R[0:nd].tolist()
I1R = I1R[0:nd].tolist()
A1R = A1R[0:nd].tolist()
#TT1 = TT1[0:nd].tolist()

# print("days:",*["%.8f"%(x) for x in T0[0:nd]])
# print("time:",*["%.8f"%(x) for x in T1[0:nd]])
# print("cases:",*["%.8f"%(x) for x in I0[0:nd]])
# print("infectd:",*["%.8f"%(x) for x in I1[0:nd]])

beta_valueR = model.sess.run(model.beta)
kappa_valueR = model.sess.run(model.kappa)
Nf_valueR = model.sess.run(model.Nf)
d_valueR = model.sess.run(model.d)


# learned parameters
print("beta:",*["%.8f"%(x) for x in beta_valueR])
print("kappa:",*["%.8f"%(x) for x in kappa_valueR])
print("Nf:",*["%.8f"%(x) for x in np.min(I0R) + (np.max(I0R) - np.min(I0R))*Nf_valueR])
print("d:",*["%.8f"%(x) for x in d_valueR])


##########################################################################################################

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter

fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title('Daily number of individual infectives in Italy',fontsize = 20)
ax1.plot(T0R,I0R,'bo')
ax1.plot(T1R, I1R,'r')
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel('Daily Omicron Infection', fontsize = 20)
ax1.legend(('Omicron data','Rational Model'),loc='best',fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter
from matplotlib import pyplot as plt
fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title(r'$\alpha(t)$ versus $t$ for Rational model',fontsize = 20)
ax1.plot(T1R, alpha_predR.flatten(),'r')
ax1.legend(('Alpha(t)','Logistic Model'),loc='best',fontsize = 20)
ax1.tick_params(axis='both', labelsize = 24)
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel(r'$\alpha(t)$', fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
rmse =np.sqrt(mean_squared_error(I0R, I1R))
rmse

# %%
corr_matrix = np.corrcoef(I0R, I1R)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mapep =  mean_absolute_percentage_error(I0R, I1R)
mapep

# %%
ev = explained_variance_score(I0R, I1R)
ev

# %% [markdown]
# ### Birational

# %%
class PINN_ExpAlpha_Birational:
    # Initialize the class
    def __init__(self, t, I,  layers1, X, lb, ub):
        
        self.lb = lb
        self.ub = ub
        
        self.t = t
        
        self.I = I
        
        self.X = X
        
        #self.b = b
        
        
        
       
        
    
        self.layers1 = layers1
        
        
        self.weights1, self.biases1 = self.initialize_NN(layers1)
       
        
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.beta = tf.Variable([2000.0], dtype=tf.float32)
        self.beta1 = tf.Variable([1.0], dtype=tf.float32)
        self.kappa = tf.Variable([1.0], dtype=tf.float32)
        self.kappa1 = tf.Variable([1.0], dtype=tf.float32)
        self.d = tf.Variable([1.0], dtype=tf.float32)
        self.d1 = tf.Variable([1.0], dtype=tf.float32)
        self.c1 = tf.Variable([1.0], dtype=tf.float32)
        self.c = tf.Variable([1.0], dtype=tf.float32)
        self.Nf = tf.Variable([1.0], dtype=tf.float32)
        
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.I_tf = tf.placeholder(tf.float32, shape=[None, self.I.shape[1]])
                       
        
        self.I_predB = self.net_Logistic(self.t_tf)
        self.alpha_predB = self.alphaFunc(self.t_tf)
        
        
        self.l1,self.l2  = self.net_l(self.t_tf)
             
        self.loss = tf.reduce_mean(tf.square(self.I_tf - self.I_predB)) + \
                    tf.reduce_mean(tf.square(self.l1)) + \
                    tf.reduce_mean(tf.square(self.l2)) 
                    
                    
            
        
        self.optimizer = tf.train.AdamOptimizer(1e-2)
        self.train_op = self.optimizer.minimize(self.loss)
        self.loss_log = []
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, t, layers1, weights1, biases1):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights1[l]
            b = biases1[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights1[-1]
        b = biases1[-1]
        #Y = tf.nn.softplus(tf.add(tf.matmul(H, W), b))
        Y = tf.add(tf.matmul(H, W), b)
        return Y

   
    
    
    def net_Logistic(self, t):
        Logistic = self.neural_net(t, self.layers1, self.weights1, self.biases1)
        I = Logistic
        return I
    
    
    def alphaFunc(self,t):
        X = self.X
        kappa = self.kappa
        d = self.d
        t1 = t[0:X]
        alp1 = kappa*d / (1 + d*t1)
        
        #b = self.b
        d1 = self.d1
        c1 = self.c1
        Nf = self.Nf
        kappa1 = self.kappa1
        t2 = t[X-1:]
        b1 = kappa1*d1 / (1 + d1*t2)
        b2 = 1 / (1 + ((1 -(c1/Nf))*(1 + d1*t2)**-kappa1))
        alp2 = tf.multiply(b1,b2)
        
        alp =  tf.concat([alp1,alp2],0)
        
        return alp2
        # bound_b = [tf.constant(0.01, dtype=tf.float32), tf.constant(1.0, dtype=tf.float32)] 
        # return bound_b[0]+(bound_b[1]-bound_b[0])*tf.sigmoid(alp2)

    
    
    
    
    def net_l(self, t):
        X = 60
        c = self.c
        c1 = self.c1
        d = self.d
        d1 = self.d1
        beta = self.beta
        beta1 = self.beta1
        kappa = self.kappa
        kappa1 = self.kappa1
        
        
        alpha = self.alphaFunc(t)
        I = self.net_Logistic(t)
        
        I_t = tf.gradients(I, t)[0]
        
        t1 = t[0:X]
        I1 = I[0:X]
        l1 = I1 - (c/(1+beta*(1 + d*t1)**-kappa))
        
        t2 = t[X-1:]
        I2 = I[X-1:]
        l2 = I2 - (((c/(1+beta*(1 + d*X)**-kappa))-(c1/(1+beta1*(1 + d1*X)**-kappa1))+(c1/(1+beta1*(1 + d1*t2)**-kappa1))))
        
        
        
        
        return l1,l2   
    
        
    def train(self, nIter):
        tf_dict = {self.t_tf: self.t, self.I_tf: self.I}
        start_time = timeit.default_timer()

        for it in tqdm(range(nIter)):
            self.sess.run(self.train_op, tf_dict)
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                self.loss_log.append(loss_value)
                beta_value = self.sess.run(self.beta)
                beta1_value = self.sess.run(self.beta1)
                d_value = self.sess.run(self.d)
                d1_value = self.sess.run(self.d1)
                c1_value = self.sess.run(self.c1)
                c_value = self.sess.run(self.c)
                kappa_value = self.sess.run(self.kappa)
                kappa1_value = self.sess.run(self.kappa1)
                Nf_value = self.sess.run(self.Nf)
                start_time = timeit.default_timer()
        
        
        
    def predict(self, t_star):
        tf_dict = {self.t_tf: t_star}
        
        
        I_star = self.sess.run(self.I_predB, tf_dict)
        
        alpha_star = self.sess.run(self.alpha_predB, tf_dict)
        
        #tt_star = self.sess.run(self.tt_pred, tf_dict)
        
        return I_star,  alpha_star

# %%
##########################################################################################################
# training the network

niter = 25000  # number of Epochs
layers1 = [1, 20, 20, 20, 20, 1]


t_train = Td.flatten()[:,None]
I_train = cs_I.flatten()[:,None]
    
#D_train = cs_D.flatten()[:,None]      

# Doman bounds
lb = t_train.min(0)
ub = t_train.max(0)

model = PINN_ExpAlpha_Birational(t_train, I_train, layers1, 1, lb, ub)
model.train(niter)

# %%
# prediction
I_predB,  alpha_predB = model.predict(t_train)

# %%
mse_train_loss = model.loss_log
rmse_train_loss = np.sqrt(mse_train_loss)
#print("rmse_train_loss:",*["%.8f"%(x) for x in rmse_train_loss[0:400]])

# flatten array
T0B = Td.flatten()
T1B = t_train.flatten()


# re-scale data
I0B = np.min(I) + (np.max(I) - np.min(I))*cs_I.flatten()
I1B = np.min(I) + (np.max(I) - np.min(I))*I_predB.flatten()
A1B = np.min(I) + (np.max(I) - np.min(I))*alpha_predB.flatten()

# convert float to list
T0B = T0B[0:nd].tolist()
T1B = T1B[0:nd].tolist()
I0B = I0B[0:nd].tolist()
I1B = I1B[0:nd].tolist()
A1B = A1B[0:nd].tolist()

# print("days:",*["%.8f"%(x) for x in T0[0:nd]])
# print("time:",*["%.8f"%(x) for x in T1[0:nd]])
# print("cases:",*["%.8f"%(x) for x in I0[0:nd]])
# print("infectd:",*["%.8f"%(x) for x in I1[0:nd]])

beta_valueB = model.sess.run(model.beta)
beta1_valueB = model.sess.run(model.beta1)
kappa_valueB = model.sess.run(model.kappa)
Nf_valueB = model.sess.run(model.Nf)
d_valueB = model.sess.run(model.d)
d1_valueB = model.sess.run(model.d1)
kappa1_valueB = model.sess.run(model.kappa1)
c1_valueB = model.sess.run(model.c1)
c_valueB = model.sess.run(model.c)

# learned parameters
print("beta:",*["%.8f"%(x) for x in beta_valueB])
print("beta1:",*["%.8f"%(x) for x in beta1_valueB])
print("kappa:",*["%.8f"%(x) for x in kappa_valueB])
print("c:",*["%.8f"%(x) for x in np.min(I0B) + (np.max(I0B) - np.min(I0B))*c_valueB])
print("Nf:",*["%.8f"%(x) for x in np.min(I0B) + (np.max(I0B) - np.min(I0B))*Nf_valueB])
print("d:",*["%.8f"%(x) for x in d_valueB])
print("d1:",*["%.8f"%(x) for x in d1_valueB])
print("c1:",*["%.8f"%(x) for x in np.min(I0B) + (np.max(I0B) - np.min(I0B))*c1_valueB])
print("kappa1:",*["%.8f"%(x) for x in kappa1_valueB])

##########################################################################################################

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter

fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title('Daily number of individual infectives in Italy',fontsize = 20)
ax1.plot(T0B,I0B,'bo')
ax1.plot(T1B, I1B,'brown')
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel('$I(t)$', fontsize = 20)
ax1.legend(('Omicron data','Birational Model'),loc='best',fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter
from matplotlib import pyplot as plt
fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title(r'$\alpha(t)$ versus $t$ for Birational model',fontsize = 20)
ax1.plot(T1B, alpha_predB.flatten(),'r')
ax1.legend(('Alpha(t)', 'Logistic Model'),loc='best',fontsize = 20)
ax1.tick_params(axis='both', labelsize = 24)
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel(r'$\alpha(t)$', fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
rmse =np.sqrt(mean_squared_error(I0B, I1B))
rmse

# %%
corr_matrix = np.corrcoef(I0B, I1B)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mapep =  mean_absolute_percentage_error(I0B, I1B)
mapep

# %%
ev = explained_variance_score(I0B, I1B)
ev

# %% [markdown]
# ### Time Series Model.

# %%
class PINN_ExpAlpha_Alpha:
    # Initialize the class
    def __init__(self, t, I,  layers1, layers2, lb, ub):
        
        self.lb = lb
        self.ub = ub
        
        self.t = t
        
        self.I = I
        
        
        
       
        
            
    
        self.layers1 = layers1
        self.layers2 = layers2
        
        
        
        
        self.weights1, self.biases1 = self.initialize_NN(layers1)
        self.weights2, self.biases2 = self.initialize_NN(layers2)
       
        
        
       
        
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        
        self.Nf = tf.Variable([1.0], dtype=tf.float32)
        
       
        
        
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.I_tf = tf.placeholder(tf.float32, shape=[None, self.I.shape[1]])
                       
        
        self.I_predA = self.net_Logistic(self.t_tf)
        self.alpha_predA = self.alphaFunc(self.t_tf)
        
        
        self.l1  = self.net_l(self.t_tf)
             
        self.loss = tf.reduce_mean(tf.square(self.I_tf - self.I_predA)) + \
                    tf.reduce_mean(tf.square(self.l1)) 
                     
            
                    
                    
                    
            
        
        self.optimizer = tf.train.AdamOptimizer(1e-2)
        self.train_op = self.optimizer.minimize(self.loss)
        self.loss_log = []
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, t, layers1, weights1, biases1):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights1[l]
            b = biases1[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights1[-1]
        b = biases1[-1]
        #Y = tf.nn.softplus(tf.add(tf.matmul(H, W), b))
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    
    
    def neural_net1(self, t, layers2, weights2, biases2):
        num_layers = len(layers2)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights2[l]
            b = biases2[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights2[-1]
        b = biases2[-1]
        #Y = tf.nn.softplus(tf.add(tf.matmul(H, W), b))
        Y = tf.add(tf.matmul(H, W), b)
        return Y

   
    
    
    
    def net_Logistic(self, t):
        Logistic = self.neural_net(t, self.layers1, self.weights1, self.biases1)
        I = Logistic
        return I
    
    

    def alphaFunc(self,t):
        alpha = self.neural_net1(t, self.layers2, self.weights2, self.biases2)
        alp = alpha
        #return alp
        bound_b = [tf.constant(0.01, dtype=tf.float32), tf.constant(1.0, dtype=tf.float32)] 
        return bound_b[0]+(bound_b[1]-bound_b[0])*tf.sigmoid(alp)

    
    
    def net_l(self, t):
        Nf = self.Nf
        
        
        alpha = self.alphaFunc(t)
        I = self.net_Logistic(t)
        
        I_t = tf.gradients(I, t)[0]
        
        
        #l1 = I - (Nf/(1+beta*tf.math.exp(-alpha*t)))
        
        l1 = I_t - ((alpha*I)*(1 - I/Nf))
        
        
        return l1
    
        
    def train(self, nIter):
        tf_dict = {self.t_tf: self.t, self.I_tf: self.I}
        start_time = timeit.default_timer()

        for it in tqdm(range(nIter)):
            self.sess.run(self.train_op, tf_dict)
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                self.loss_log.append(loss_value)
                Nf_value = self.sess.run(self.Nf)
                start_time = timeit.default_timer()
        
        
        
    def predict(self, t_star):
        tf_dict = {self.t_tf: t_star}
        
        
        I_star = self.sess.run(self.I_predA, tf_dict)
        
        alpha_star = self.sess.run(self.alpha_predA, tf_dict)
        
        
        return I_star,  alpha_star

# %%
# ##########################################################################################################
# training the network

niter = 25000  # number of Epochs
layers1 = [1, 20, 20, 20, 20, 1]
layers2 = [1, 20, 20, 20, 20, 1]



t_train = Td.flatten()[:,None]
I_train = cs_I.flatten()[:,None]
    
#D_train = cs_D.flatten()[:,None]      

# Doman bounds
lb = t_train.min(0)
ub = t_train.max(0)

model = PINN_ExpAlpha_Alpha(t_train, I_train, layers1, layers2, lb, ub)
model.train(niter)
# Out:
# Device mapping: no known devices.
# 2022-09-26 22:29:38.438936: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-26 22:29:38.441854: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-26 22:29:38.441878: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-26 22:29:38.441906: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyter-eo3j): /proc/driver/nvidia/version does not exist
# 2022-09-26 22:29:38.824221: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824352: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824360: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824368: I tensorflow/core/common_runtime/placer.cc:114] Variable: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824375: I tensorflow/core/common_runtime/placer.cc:114] Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824381: I tensorflow/core/common_runtime/placer.cc:114] Variable/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824387: I tensorflow/core/common_runtime/placer.cc:114] Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824393: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824398: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824404: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824410: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824416: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824422: I tensorflow/core/common_runtime/placer.cc:114] Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824428: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824433: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824439: I tensorflow/core/common_runtime/placer.cc:114] Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824445: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824450: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.824456: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal
(AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825720: I tensorflow/core/common_runtime/placer.cc:114] Tanh_5: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825727: I tensorflow/core/common_runtime/placer.cc:114] MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825734: I tensorflow/core/common_runtime/placer.cc:114] Add_7: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825741: I tensorflow/core/common_runtime/placer.cc:114] Tanh_6: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825748: I tensorflow/core/common_runtime/placer.cc:114] MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825755: I tensorflow/core/common_runtime/placer.cc:114] Add_8: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825762: I tensorflow/core/common_runtime/placer.cc:114] Tanh_7: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825769: I tensorflow/core/common_runtime/placer.cc:114] MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825776: I tensorflow/core/common_runtime/placer.cc:114] Add_9: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825785: I tensorflow/core/common_runtime/placer.cc:114] sub_4: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825792: I tensorflow/core/common_runtime/placer.cc:114] Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825799: I tensorflow/core/common_runtime/placer.cc:114] mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825806: I tensorflow/core/common_runtime/placer.cc:114] add_10: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825813: I tensorflow/core/common_runtime/placer.cc:114] sub_5: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825821: I tensorflow/core/common_runtime/placer.cc:114] mul_3: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825828: I tensorflow/core/common_runtime/placer.cc:114] truediv_2: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825836: I tensorflow/core/common_runtime/placer.cc:114] sub_6: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825843: I tensorflow/core/common_runtime/placer.cc:114] MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825850: I tensorflow/core/common_runtime/placer.cc:114] Add_11: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825857: I tensorflow/core/common_runtime/placer.cc:114] Tanh_8: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825864: I tensorflow/core/common_runtime/placer.cc:114] MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825871: I tensorflow/core/common_runtime/placer.cc:114] Add_12: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825879: I tensorflow/core/common_runtime/placer.cc:114] Tanh_9: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825886: I tensorflow/core/common_runtime/placer.cc:114] MatMul_12: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825893: I tensorflow/core/common_runtime/placer.cc:114] Add_13: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825900: I tensorflow/core/common_runtime/placer.cc:114] Tanh_10: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825907: I tensorflow/core/common_runtime/placer.cc:114] MatMul_13: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825915: I tensorflow/core/common_runtime/placer.cc:114] Add_14: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825923: I tensorflow/core/common_runtime/placer.cc:114] Tanh_11: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825930: I tensorflow/core/common_runtime/placer.cc:114] MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825937: I tensorflow/core/common_runtime/placer.cc:114] Add_15: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825946: I tensorflow/core/common_runtime/placer.cc:114] sub_7: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825953: I tensorflow/core/common_runtime/placer.cc:114] Sigmoid_1: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825960: I tensorflow/core/common_runtime/placer.cc:114] mul_4: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825967: I tensorflow/core/common_runtime/placer.cc:114] add_16: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825974: I tensorflow/core/common_runtime/placer.cc:114] sub_8: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825982: I tensorflow/core/common_runtime/placer.cc:114] mul_5: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825990: I tensorflow/core/common_runtime/placer.cc:114] truediv_3: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.825999: I tensorflow/core/common_runtime/placer.cc:114] sub_9: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826006: I tensorflow/core/common_runtime/placer.cc:114] MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826017: I tensorflow/core/common_runtime/placer.cc:114] Add_17: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826024: I tensorflow/core/common_runtime/placer.cc:114] Tanh_12: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826031: I tensorflow/core/common_runtime/placer.cc:114] MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.
(Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826815: I tensorflow/core/common_runtime/placer.cc:114] gradients/mul_5_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826823: I tensorflow/core/common_runtime/placer.cc:114] gradients/mul_5_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826832: I tensorflow/core/common_runtime/placer.cc:114] gradients/mul_5_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826843: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826853: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826861: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826870: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826878: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826886: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826896: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826904: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_8_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826914: I tensorflow/core/common_runtime/placer.cc:114] mul_6: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826922: I tensorflow/core/common_runtime/placer.cc:114] truediv_4: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826933: I tensorflow/core/common_runtime/placer.cc:114] sub_10: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826941: I tensorflow/core/common_runtime/placer.cc:114] mul_7: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826949: I tensorflow/core/common_runtime/placer.cc:114] sub_11: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826959: I tensorflow/core/common_runtime/placer.cc:114] sub_12: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826967: I tensorflow/core/common_runtime/placer.cc:114] Square: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826975: I tensorflow/core/common_runtime/placer.cc:114] Mean: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826988: I tensorflow/core/common_runtime/placer.cc:114] Square_1: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.826996: I tensorflow/core/common_runtime/placer.cc:114] Mean_1: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827005: I tensorflow/core/common_runtime/placer.cc:114] add_22: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827014: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827034: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/add_22_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827041: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/add_22_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827049: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/add_22_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827057: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827066: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827074: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827082: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827092: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827099: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Prod_1: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827109: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Maximum: (Maximum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827117: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/floordiv: (FloorDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827125: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827135: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827143: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827150: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827157: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827165: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827174: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827185: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Prod_1: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827193: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Maximum: (Maximum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827201: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/floordiv: (FloorDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827211: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827220: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Mean_1_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827229: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Square_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827238: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Square_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827247: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Square_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827255: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/Square_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827267: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827276: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827284: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827292: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827301: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827309: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827317: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827331: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2022-09-26 22:29:38.827340: I tensorflow/core/common_runtime/placer.cc:114] gradients_1/sub_12_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# Variable_16/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_1/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_2/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_3/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_4/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_5/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_6/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_7/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_8/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_9/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_10/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_11/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_12/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_13/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_14/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_15/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_16/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_17/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_18/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_19/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Variable_20/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/Assign_1: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Adam: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# init: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_6: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_7: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_8: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# zeros_9: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Placeholder: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# Placeholder_1: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# mul/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# mul_1/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truediv_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_3/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_5/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# mul_3/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truediv_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_6/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_8/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# mul_5/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# truediv_3/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_9/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/grad_ys_0/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/truediv_3_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# sub_10/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/grad_ys_0/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_grad/Shape_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_grad/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_grad/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_grad/Maximum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_1_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_1_grad/Shape_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_1_grad/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_1_grad/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Mean_1_grad/Maximum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Square_grad/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Square_1_grad/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_8_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_8_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_8_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_8_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/truediv_4_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/mul_5_grad/Sum_1_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/mul_5_grad/Sum_1_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/mul_5_grad/Sum_1_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/mul_5_grad/Sum_1_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/truediv_3_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/truediv_3_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/truediv_3_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/truediv_3_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/truediv_3_grad/RealDiv_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_9_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_9_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_9_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/sub_9_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_17_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_17_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_17_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_17_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_12_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_18_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_18_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_18_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_18_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_13_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_19_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_19_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_19_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_19_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_14_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_20_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_20_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_20_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Add_20_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_15_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Adam/Initializer/zeros: (Const): /job:localhost/rep
# 100%|██████████| 25000/25000 [00:31<00:00, 796.73it/s]

# %%
# prediction
I_predA,  alpha_predA = model.predict(t_train)

# %%
mse_train_loss = model.loss_log
rmse_train_loss = np.sqrt(mse_train_loss)
#print("rmse_train_loss:",*["%.8f"%(x) for x in rmse_train_loss[0:400]])

# flatten array
T0A = Td.flatten()
T1A = t_train.flatten()


# re-scale data
I0A = np.min(I) + (np.max(I) - np.min(I))*cs_I.flatten()
I1A = np.min(I) + (np.max(I) - np.min(I))*I_predA.flatten()
A1A = np.min(I) + (np.max(I) - np.min(I))*alpha_predA.flatten()

# convert float to list
T0A = T0A[0:nd].tolist()
T1A = T1A[0:nd].tolist()
I0A = I0A[0:nd].tolist()
I1A = I1A[0:nd].tolist()
A1A = A1A[0:nd].tolist()

# print("days:",*["%.8f"%(x) for x in T0[0:nd]])
# print("time:",*["%.8f"%(x) for x in T1[0:nd]])
# print("cases:",*["%.8f"%(x) for x in I0[0:nd]])
# print("infectd:",*["%.8f"%(x) for x in I1[0:nd]])

Nf_valueA = model.sess.run(model.Nf)




# learned parameters
print("Nf:",*["%.8f"%(x) for x in np.min(I0A) + (np.max(I0A) - np.min(I0A))*Nf_valueA])



##########################################################################################################
# Out:
# Nf: 178154.15625000

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter

fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title('Daily number of individual infectives in Italy',fontsize = 20)
ax1.plot(T0A,I0A,'bo')
ax1.plot(T1A, I1A,'g')
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel('Daily Omicron Infection', fontsize = 20)
ax1.legend(('Omicron data','Time-series Model'),loc='best',fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
from datetime import datetime
from matplotlib.dates import date2num, DayLocator, DateFormatter
from matplotlib import pyplot as plt
fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title(r'$\alpha(t)$ versus $t$ for Time-series model for Italy',fontsize = 20)
ax1.plot(T1A, alpha_predA.flatten(),'k')
ax1.legend(('Alpha(t)', 'Logistic Model'),loc='best',fontsize = 20)
ax1.tick_params(axis='both', labelsize = 24)
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel(r'$\alpha(t)$', fontsize = 20)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=15)

# %%
rmse =np.sqrt(mean_squared_error(I0A, I1A))
rmse
# Out:
# 1338.5370593842379

# %%
corr_matrix = np.corrcoef(I0A, I1A)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)
# Out:
# 0.9992891858407056

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mapep =  mean_absolute_percentage_error(I0A, I1A)
mapep
# Out:
# 1.7855230173084928

# %%
ev = explained_variance_score(I0A, I1A)
ev
# Out:
# 0.999286692246855

# %%
from scipy.integrate import odeint

# %%
def function(I, t, alpha, Nf):
    dIdt = alpha*I*(1 - (I/Nf))
    return dIdt

# %%
alpha = alpha_predA[-1]
Nf = Nf_valueA
I_p = I_predA[-1]

# %%
tt = np.linspace(160,185)
I_PP = np.min(I0A) + (np.max(I0A) - np.min(I0A))*odeint(function, I_p, tt, args=(alpha, Nf))
tt1 =np.linspace(0,160)

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(10, 7))
#fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(25, 7))


ax1.set_title('Time-series Model for the Predition of Omicron infectives in Italy',fontsize = 20)
ax1.plot(T0A,I0A,'bo')
ax1.plot(T1A, I1A,'g')
ax1.plot(tt, I_PP,'k--')
ax1.set_xlabel('Days', fontsize = 20)
ax1.set_ylabel('Daily Omicron Infection', fontsize = 20)
ax1.legend(('Omicron Data','Time-series model', 'prediction'),loc='best',fontsize = 10)
fig.set_size_inches(w=13,h=8.5)
ax1.tick_params(labelsize=10)

# %%
I_PP[-1]
# Out:
# array([51532.81400528])
